# %% [markdown]
# In this lab, we will create some models which will predict the price of the car using the variables or features

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# ---
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
x = df[['highway-mpg','normalized-losses','horsepower']]
y = df['price']
lm = LinearRegression()
lm.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
yhat = lm.predict(x)
print('Intercept: ',lm.intercept_)
print('Coef: ', lm.coef_)
print('R-squared: ', lm.score(x,y))
# Out:
# Intercept:  4689.227432798845
# Coef:  [-177.38621513  -11.20755061  148.23768632]
# R-squared:  0.6654150636442466

# %% [markdown]
# ---
# ### Visualization

# %%
import seaborn as sns
sns.set()

# %%
plt.figure(figsize=(12,10))
sns.regplot(data = df,x = 'highway-mpg', y ='price')
plt.ylim(0,)
plt.show()

# %%
sns.residplot(data = df, x ='normalized-losses', y ='price')
plt.show()

# %%
df[['highway-mpg', 'normalized-losses', 'price']].corr()
# Out:
#                    highway-mpg  normalized-losses     price
# highway-mpg           1.000000          -0.181877 -0.704692
# normalized-losses    -0.181877           1.000000  0.133999
# price                -0.704692           0.133999  1.000000

# %%
plt.figure(figsize = (6,5))
ax1 = sns.distplot(y,hist=False, color='b', label ='Actual Value')
sns.distplot(yhat,hist=False, color='r',ax = ax1, label = 'Predicted Value')
plt.title('Acutal Price vs Predicted Price')
plt.xlabel('Number of cars')
plt.ylabel('Price')
plt.show()
plt.close()

# %% [markdown]
# ---
# ### PolyNominal

# %%
# Define variables:
x = df['highway-mpg']
y = df['price']

# %%
#Calculate the polynominal
f = np.polyfit(x,y,3)
p = np.poly1d(f)
print(p)
# Out:
#         3         2
# -1.557 x + 204.8 x - 8965 x + 1.379e+05

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr = PolynomialFeatures (degree = 2, include_bias = False, interaction_only =False)
pr
# Out:
# PolynomialFeatures(degree=2, include_bias=False, interaction_only=False,
#                    order='C')

# %%
z = df[['highway-mpg','normalized-losses','horsepower']]
z_pr = pr.fit_transform(z)

# %%
print('Z shape:', z.shape)
print ('Z_pr: ', z_pr.shape)
# Out:
# Z shape: (201, 3)
# Z_pr:  (201, 9)

# %% [markdown]
# ---
# ### Piplines

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline

# %%
Input = [('scale', StandardScaler()), ('polynomial', PolynomialFeatures(degree = 2)),('mode', LinearRegression())]

# %%
pipe = Pipeline(Input)
pipe.fit(z,y)
yhat = pipe.predict(z)

# %%
yhat[0:4]
# Out:
# array([14352.8359432 , 14352.8359432 , 19537.4690749 , 11440.34455742])

# %%
plt.figure(figsize = (12,10))
ax1 = sns.distplot(y, hist = False, color = 'b', label = 'Actual Values')
sns.distplot(yhat, hist = False, color = 'r', label = "Predicted pipline values", ax = ax1)
plt.ylim(0,)
plt.show()

# %% [markdown]
# ---
# ### Cross validation
# when the data is not large enough to be split into train and test sets, we use cross_val_score

# %%
from sklearn.model_selection import cross_val_score

# %%
#Define the variables
x = df.drop('price', axis = 1)
y = df['price']
x
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            3                122  alfa-romero        std          two
# 2            1                122  alfa-romero        std          two
# 3            2                164         audi        std         four
# 4            2                164         audi        std         four
# ..         ...                ...          ...        ...          ...
# 196         -1                 95        volvo        std         four
# 197         -1                 95        volvo      turbo         four
# 198         -1                 95        volvo        std         four
# 199         -1                 95        volvo      turbo         four
# 200         -1                 95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...

# %%
#Build Model
lr1 = LinearRegression()
lr1.fit(x[['horsepower']],y)
CVS = cross_val_score(lr1, x[['horsepower']],y, cv=4)

# %%
#Calculate the R-square, the mean of the folds
print ('R-Squared = ',(lr1.score(x[['horsepower']],y)))
print ('Mean of folds = ', CVS.mean())
# Out:
# R-Squared =  0.6554109795391572
# Mean of folds =  0.522009915042119

# %%
CVS
# Out:
# array([0.7746232 , 0.51716687, 0.74785353, 0.04839605])

# %% [markdown]
# ### Use the <font color = 'red'>"Cross_val_predict"</font>

# %%
from sklearn.model_selection import cross_val_predict
yhat = cross_val_predict(lr1, x[['horsepower']], y, cv = 4)
yhat[:4]
# Out:
# array([14141.63807508, 14141.63807508, 20814.29423473, 12745.03562306])

# %% [markdown]
# ---
# ## Multiple features with polynomial

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split

# %%
x_data = df[['horsepower', 'curb-weight','engine-size','highway-mpg']]
y_data = df[['price']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.3, random_state = 16)
print ('x_train size:', x_train.shape)
print('x_test size: ', x_test.shape)
# Out:
# x_train size: (140, 4)
# x_test size:  (61, 4)

# %%
pr = PolynomialFeatures(degree = 2, include_bias = False)
x_train_pr = pr.fit_transform(x_train)
x_test_pr = pr.fit_transform(x_test)
print ('Dimension of x_train_pr: ', x_train_pr.shape)
print('Dimension of x_test_pr: ', x_test_pr.shape)
# Out:
# Dimension of x_train_pr:  (140, 14)
# Dimension of x_test_pr:  (61, 14)

# %%
pr = LinearRegression()
pr.fit(x_train_pr, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
yhat = pr.predict(x_train_pr)
y_hat_test = pr.predict(x_test_pr)

# %%
plt.figure(figsize = (12,10))
ax1 = sns.distplot(y_test,hist = False, color = 'b', label = 'Actual Test dataset')
sns.distplot(y_hat_test, hist = False, color = 'r', label = 'Predicted Test dataset', ax = ax1)
plt.xlabel('Price',)
plt.ylabel('Proportion of cars')
plt.title ('Distribution of Actual Target Values and Predicted Target Values')
plt.show()
plt.close()

# %%
# plot the residual plot
ax2 = sns.residplot(y_hat_test, y_test,color = 'r' )
sns.residplot(yhat, y_train, color = 'b', ax = ax2)
plt.show()

# %% [markdown]
# ---
# ## Ridge Regression
#
# Use alpha to prevent overfiiting

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr = PolynomialFeatures(degree = 2, include_bias = False)
x_train_pr = pr.fit_transform(x_train)
x_test_pr = pr.fit_transform(x_test)

# %%
from sklearn.linear_model import Ridge

# %%
RidgeModel = Ridge(alpha = 1)
RidgeModel.fit(x_train_pr,y_train)
print('R^2 values of training dataset: ',RidgeModel.score(x_train_pr,y_train ))
print ('R^2 values of testing dataset:', RidgeModel.score(x_test_pr, y_test))
# Out:
# R^2 values of training dataset:  0.8490787752818763
# R^2 values of testing dataset: 0.7874891786615413

# %%
yhat_Ridge = RidgeModel.predict(x_test_pr)

# %%
plt.figure(figsize = (12,10))
ax1 = sns.distplot(y_test,hist = False, color = 'b', label = 'Actual Test dataset')
sns.distplot(yhat_Ridge, hist = False, color = 'r', label = 'Predicted - Ridge', ax = ax1)
sns.distplot(y_hat_test, hist = False, color = 'y', label = 'Predicted - Linear', ax = ax1)
plt.xlabel('Price',)
plt.ylabel('Proportion of cars')
plt.title ('Distribution of Actual Target Values and Predicted Target Values')
plt.show()
plt.close()

# %% [markdown]
# ---
# ## Grid Search
#
# Allows us to scan through the free hyperparameter (ex. alpha in Ridge Model)

# %%
from sklearn.model_selection import GridSearchCV

# %%
hyperpara = [{'alpha': [0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000, 100000, 1000000]}]
Ridge_Grid = Ridge()
GridSearch1 = GridSearchCV(Ridge_Grid, hyperpara, cv =3)
GridSearch1.fit(x_train_pr, y_train)
# Out:
# GridSearchCV(cv=3, error_score=nan,
#              estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=None, normalize=False, random_state=None,
#                              solver='auto', tol=0.001),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'alpha': [0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000,
#                                     100000, 1000000]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
best_alpha = GridSearch1.best_estimator_

#Find the R^2 value of the best estimator
best_alpha.score(x_test_pr, y_test)
# Out:
# 0.7831157973872039
